# %%
import pandas as pd
import numpy as np
import glob  
import plotly.graph_objs as go
import plotly.offline as py
import matplotlib.pyplot as plt               # Visualização de dados
import matplotlib
plt.style.use('fivethirtyeight') 
import squarify
from datetime import datetime
from folium import Map
from folium.plugins import HeatMap

# %%
# FUNÇÃO PARA IMPORTAR DATASET

dir_path = "data/"

def importaData(files):
    
    data = dir_path + files
    allFiles = glob.glob('data/*.csv')
    list_ = []
    dtypes = {
        'ANO_BO': object,
        'NUM_BO': object,
        'DATAOCORRENCIA': object,
        'PERIDOOCORRENCIA':object,
        'BAIRRO':object,
        'CIDADE':object,
        'LATITUDE':object,
        'LONGITUDE':object,
        'LOGRADOURO':object,
        'DESCRICAOLOCAL':object,
        'DESCR_TIPO_VEICULO':object,
        'DELEGACIA_NOME': object,
        'QUANT_CELULAR': object
    }
    cols = ['ANO_BO', 'NUM_BO', 'DATAOCORRENCIA', 'PERIDOOCORRENCIA', 'BAIRRO', 'CIDADE', 'LATITUDE', 'LONGITUDE', 'LOGRADOURO', \
           'DESCRICAOLOCAL', 'DESCR_TIPO_VEICULO', 'DELEGACIA_NOME',  'QUANT_CELULAR']

    for file_ in allFiles:
        df = pd.read_csv(file_,index_col=None, header=0, delimiter=';', usecols=cols, dtype=dtypes, thousands=',')
        list_.append(df)

    df = pd.concat(list_, axis = 0, ignore_index = True)
    return df

# IMPORTANDO DATASET

dataset = importaData('*.csv')

# %%
# REMOVENDO DADOS DUPLICADOS

def removeDuplicados(df):
    df.drop_duplicates(subset=['DELEGACIA_NOME', 'ANO_BO', 'NUM_BO'], inplace=True)
    df.reset_index(drop=True,inplace=True)
    return df

dataset = removeDuplicados(dataset)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278175 entries, 0 to 1278174
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ANO_BO              1278175 non-null  object
#  1   NUM_BO              1278175 non-null  object
#  2   DATAOCORRENCIA      1278172 non-null  object
#  3   PERIDOOCORRENCIA    1278174 non-null  object
#  4   LOGRADOURO          1224442 non-null  object
#  5   BAIRRO              1093579 non-null  object
#  6   CIDADE              1235274 non-null  object
#  7   LATITUDE            1090572 non-null  object
#  8   LONGITUDE           1090570 non-null  object
#  9   DESCRICAOLOCAL      1278173 non-null  object
#  10  DELEGACIA_NOME      1278172 non-null  object
#  11  DESCR_TIPO_VEICULO  162023 non-null   object
#  12  QUANT_CELULAR       932206 non-null   object
# dtypes: object(13)
# memory usage: 126.8+ MB

# %%
dataset['ANO_BO'] = pd.to_numeric(dataset['ANO_BO'], errors='coerce', downcast='integer')

# %%
dataset['ANO_BO'].isnull().sum()
# Out:
# 2

# %%
dataset[dataset['ANO_BO'].isnull()]
# Out:
#          ANO_BO            NUM_BO    DATAOCORRENCIA PERIDOOCORRENCIA  \
# 212747      NaN      Desconhecida                 1            AREAO
# 1186312     NaN  18/11/2010 23:26  18/11/2010 23:02     Desconhecida
#
#         LOGRADOURO                   BAIRRO            CIDADE  \
# 212747         NaN  DEL.SEC.TAUBATE PLANTÃO  02º D.P. TAUBATE
# 1186312    S.PAULO                      NaN               NaN
#
#                               LATITUDE             LONGITUDE  \
# 212747   Roubo (art. 157) - TRANSEUNTE                   NaN
# 1186312                            NaN  BO PARA INVESTIGAÇÃO
#
#                   DESCRICAOLOCAL                              DELEGACIA_NOME  \
# 212747                 Consumado                                         NaN
# 1186312  83º D.P. PARQUE BRISTOL  Localização/Apreensão e Entrega de veículo
#
#         DESCR_TIPO_VEICULO QUANT_CELULAR
# 212747                 NaN           NaN
# 1186312                NaN           NaN

# %%
dataset['NUM_BO'] = pd.to_numeric(dataset['NUM_BO'], errors='coerce', downcast='integer')

# %%
dataset[dataset['NUM_BO'].isnull()]
# Out:
#          ANO_BO  NUM_BO    DATAOCORRENCIA PERIDOOCORRENCIA LOGRADOURO  \
# 212747      NaN     NaN                 1            AREAO        NaN
# 1084328  2005.0     NaN               NaN              NaN        NaN
# 1186312     NaN     NaN  18/11/2010 23:02     Desconhecida    S.PAULO
#
#                           BAIRRO            CIDADE  \
# 212747   DEL.SEC.TAUBATE PLANTÃO  02º D.P. TAUBATE
# 1084328                      NaN               NaN
# 1186312                      NaN               NaN
#
#                               LATITUDE             LONGITUDE  \
# 212747   Roubo (art. 157) - TRANSEUNTE                   NaN
# 1084328                            NaN                   NaN
# 1186312                            NaN  BO PARA INVESTIGAÇÃO
#
#                   DESCRICAOLOCAL                              DELEGACIA_NOME  \
# 212747                 Consumado                                         NaN
# 1084328                      NaN                                         NaN
# 1186312  83º D.P. PARQUE BRISTOL  Localização/Apreensão e Entrega de veículo
#
#         DESCR_TIPO_VEICULO QUANT_CELULAR
# 212747                 NaN           NaN
# 1084328                NaN           NaN
# 1186312                NaN           NaN

# %%
dataset['LATITUDE'] = dataset['LATITUDE'].replace({',':'.'}, regex=True)
dataset['LONGITUDE'] = dataset['LONGITUDE'].replace({',':'.'}, regex=True)

# %%
dataset['LATITUDE'] = pd.to_numeric(dataset['LATITUDE'], errors='coerce')
dataset['LONGITUDE'] = pd.to_numeric(dataset['LONGITUDE'], errors='coerce')

# %%
dataset['QUANT_CELULAR'] = pd.to_numeric(dataset['QUANT_CELULAR'], errors='coerce')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1278175 entries, 0 to 1278174
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   ANO_BO              1278173 non-null  float64
#  1   NUM_BO              1278172 non-null  float64
#  2   DATAOCORRENCIA      1278172 non-null  object
#  3   PERIDOOCORRENCIA    1278174 non-null  object
#  4   LOGRADOURO          1224442 non-null  object
#  5   BAIRRO              1093579 non-null  object
#  6   CIDADE              1235274 non-null  object
#  7   LATITUDE            1090571 non-null  float64
#  8   LONGITUDE           1090569 non-null  float64
#  9   DESCRICAOLOCAL      1278173 non-null  object
#  10  DELEGACIA_NOME      1278172 non-null  object
#  11  DESCR_TIPO_VEICULO  162023 non-null   object
#  12  QUANT_CELULAR       932205 non-null   float64
# dtypes: float64(5), object(8)
# memory usage: 126.8+ MB

# %%
dataset[dataset['QUANT_CELULAR'].isnull()]
# Out:
#          ANO_BO  NUM_BO DATAOCORRENCIA PERIDOOCORRENCIA  \
# 1        2011.0  2222.0     01/06/2011     DE MADRUGADA
# 4        2011.0  4331.0     31/05/2011          A NOITE
# 7        2011.0  6486.0     31/05/2011          A NOITE
# 10       2011.0  3360.0     31/05/2011          A NOITE
# 16       2011.0  6489.0     01/06/2011     DE MADRUGADA
# ...         ...     ...            ...              ...
# 1278078  2015.0  3962.0     30/04/2015          A TARDE
# 1278094  2015.0  2038.0     30/04/2015          A TARDE
# 1278127  2015.0  5293.0     28/04/2015          A NOITE
# 1278130  2015.0  3527.0     30/04/2015          A NOITE
# 1278132  2015.0  1331.0     30/04/2015          A NOITE
#
#                          LOGRADOURO               BAIRRO   CIDADE   LATITUDE  \
# 1                 R ANTONIO GANDINI  CONJ.JOSE BONIFACIO  S.PAULO -23.541350
# 4              R BENEDITO BERNARDES             VILA EMA  S.PAULO -23.580824
# 7                 R MARIA CURUPAITI                  NaN  S.PAULO -23.506671
# 10       AC PONTE DA VILA GUILHERME                  NaN  S.PAULO -23.522149
# 16                              NaN                  NaN      NaN        NaN
# ...                             ...                  ...      ...        ...
# 1278078                         NaN                  NaN      NaN        NaN
# 1278094           RUA FERREIRA PENA          RIO PEQUENO  S.PAULO -23.569223
# 1278127       AVENIDA RAGUEB CHOHFI             IGUATEMI  S.PAULO -23.595131
# 1278130      RUA INOCENCIO SERAFICO           VILA SONIA  S.PAULO -23.600190
# 1278132      RUA MADALENA MADUREIRA                LIMAO  S.PAULO -23.504454
#
#          LONGITUDE DESCRICAOLOCAL            DELEGACIA_NOME  \
# 1       -46.445806    Via pública  103º D.P. COHABII/ITAQU.
# 4       -46.543110    Via pública      56º D.P. VILA ALPINA
# 7       -46.640113    Via pública       13º D.P. CASA VERDE
# 10      -46.611024    Via pública         23º D.P. PERDIZES
# 16             NaN     Residência       13º D.P. CASA VERDE
# ...            ...            ...                       ...
# 1278078        NaN    Via pública    101º D.P. JDIM IMBUIAS
# 1278094 -46.747355    Via pública          93º D.P. JAGUARÉ
# 1278127 -46.439501    Via pública       49º D.P. SAO MATEUS
# 1278130 -46.735025    Via pública    89º D.P. JARDIM TABOAO
# 1278132 -46.668256    Via pública   40º D.P. VILA STA MARIA
#
#         DESCR_TIPO_VEICULO  QUANT_CELULAR
# 1                      NaN            NaN
# 4                      NaN            NaN
# 7                AUTOMOVEL            NaN
# 10                     NaN            NaN
# 16                     NaN            NaN
# ...                    ...            ...
# 1278078          AUTOMOVEL            NaN
# 1278094                NaN            NaN
# 1278127                NaN            NaN
# 1278130          AUTOMOVEL            NaN
# 1278132          AUTOMOVEL            NaN
#
# [345970 rows x 13 columns]

# %%
dataset.reset_index(drop='index',inplace=True)

# %%
dataset[dataset['LONGITUDE'].isnull()]
# Out:
#          ANO_BO    NUM_BO DATAOCORRENCIA PERIDOOCORRENCIA  \
# 0        2011.0    4486.0     31/05/2011          A NOITE
# 2        2011.0    2447.0     31/05/2011          A NOITE
# 16       2011.0    6489.0     01/06/2011     DE MADRUGADA
# 18       2011.0    3496.0     31/05/2011          A NOITE
# 28       2011.0    3710.0     01/06/2011     DE MADRUGADA
# ...         ...       ...            ...              ...
# 1278165  2015.0  542071.0     30/04/2015          A NOITE
# 1278166  2015.0  542072.0     30/04/2015          A NOITE
# 1278167  2015.0  542096.0     30/04/2015          A NOITE
# 1278169  2015.0  542125.0     30/04/2015          A NOITE
# 1278170  2015.0  542079.0     30/04/2015       PELA MANHÃ
#
#                       LOGRADOURO              BAIRRO   CIDADE  LATITUDE  \
# 0                            NaN                 NaN      NaN       NaN
# 2                            NaN                 NaN      NaN       NaN
# 16                           NaN                 NaN      NaN       NaN
# 18                           NaN                 NaN      NaN       NaN
# 28                           NaN                 NaN      NaN       NaN
# ...                          ...                 ...      ...       ...
# 1278165           Rua: Borromini     Jardim São Luiz  S.PAULO       NaN
# 1278166       Rua Calógero Calia  Vila Santo Stéfano  S.PAULO       NaN
# 1278167               Rua Orense              IMIRIM  S.PAULO       NaN
# 1278169            CONSOLAÇÃO 68          consolaçao  S.PAULO       NaN
# 1278170  Rua Conselheiro Ramalho          BELA VISTA  S.PAULO       NaN
#
#          LONGITUDE DESCRICAOLOCAL            DELEGACIA_NOME  \
# 0              NaN     Residência          30º D.P. TATUAPE
# 2              NaN     Residência  53º D.P. PARQUE DO CARMO
# 16             NaN     Residência       13º D.P. CASA VERDE
# 18             NaN     Residência      51º D.P. RIO PEQUENO
# 28             NaN     Residência        41º D.P. VILA RICA
# ...            ...            ...                       ...
# 1278165        NaN         Outros      DELEGACIA ELETRONICA
# 1278166        NaN         Outros      DELEGACIA ELETRONICA
# 1278167        NaN         Outros      DELEGACIA ELETRONICA
# 1278169        NaN         Outros      DELEGACIA ELETRONICA
# 1278170        NaN         Outros      DELEGACIA ELETRONICA
#
#         DESCR_TIPO_VEICULO  QUANT_CELULAR
# 0               UTILITÁRIO            1.0
# 2                AUTOMOVEL            1.0
# 16                     NaN            NaN
# 18                     NaN            1.0
# 28               AUTOMOVEL            NaN
# ...                    ...            ...
# 1278165                NaN            1.0
# 1278166          AUTOMOVEL            1.0
# 1278167                NaN            1.0
# 1278169                NaN            1.0
# 1278170                NaN            1.0
#
# [187606 rows x 13 columns]

# %%
dataset = dataset[dataset['LONGITUDE'].notnull()]

# %%
# TRANSFORMANDO STRINGS PARA LOWER CASE

def lowerCase(df, cols):
    for col in cols:
        df[col] = df[col].str.title()
    
    return df

colsToLower = ["PERIDOOCORRENCIA", "LOGRADOURO", "BAIRRO", "DESCR_TIPO_VEICULO","CIDADE"]

all_data = lowerCase(dataset, colsToLower)

# %%
all_data = all_data[all_data['CIDADE']=='S.Paulo']

# %%
all_data[all_data['LONGITUDE']==27486.0]]
# Out:
#         ANO_BO  NUM_BO DATAOCORRENCIA PERIDOOCORRENCIA  \
# 686741  2015.0  1343.0     27/05/2015          A Noite
#
#                             LOGRADOURO   BAIRRO   CIDADE   LATITUDE  \
# 686741  Rua Professor Otavio Guimaraes  Socorro  S.Paulo -46.713754
#
#         LONGITUDE       DESCRICAOLOCAL     DELEGACIA_NOME DESCR_TIPO_VEICULO  \
# 686741    27486.0  Restaurante e afins  102º D.P. SOCORRO                NaN
#
#         QUANT_CELULAR
# 686741            1.0

# %%
all_data.drop(686741, inplace=True)
# Out:
# /home/everson/miniconda3/envs/env/lib/python3.7/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
all_data['DATAOCORRENCIA'] = pd.to_datetime(all_data['DATAOCORRENCIA'], errors='coerce')
# Out:
# /home/everson/miniconda3/envs/env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# DBSCAN

# %%
X = np.array(all_data[['LATITUDE','LONGITUDE']])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)

# %%
np.unique(kmeans.labels_)
# Out:
# array([0, 1, 2, 3, 4], dtype=int32)

# %%
def number_of_clusters(dataset, n_clusters):
    wcss = []
    for n in range(2, n_clusters+1):
        kmeans = KMeans(n_clusters=n)
        kmeans.fit(dataset)
        wcss.append(kmeans.inertia_)

    x1, y1 = 2, wcss[0]
    x2, y2 = n_clusters, wcss[len(wcss)-1]

    distances = []
    for i in range(len(wcss)):
        x0 = i+2
        y0 = wcss[i]
        numerator = abs((y2-y1)*x0 - (x2-x1)*y0 + x2*y1 - y2*x1)
        denominator = np.sqrt((y2 - y1)**2 + (x2 - x1)**2)
        distances.append(numerator/denominator)
    
    return distances.index(max(distances)) + 2

# %%
results = number_of_clusters(X, 10)
results

# %%
#bairro_sp = 
all_data['BAIRRO'].value_counts()
# Out:
# Republica         17561
# Itaquera          15838
# Grajau            15261
# Itaim Paulista    14798
# Jabaquara         13669
#                   ...
# Jd João Xxii          1
# Itapejica             1
# Jdn Arize             1
# Edilene               1
# V. Nova Curuçá        1
# Name: BAIRRO, Length: 17646, dtype: int64

# %%
# m = Map([-23.64992751, -46.62569322], zoom_start=10, width='100%', height='100%')
# m.add_child(HeatMap(all_data[['LATITUDE','LONGITUDE']], radius=8))
# m

# %%
from sklearn.cluster import KMeans
kmeans_scikit = KMeans(n_clusters=50, random_state=0).fit(X)

print("Inércia = ", kmeans_scikit.inertia_)

plt.scatter(X[:,0], X[:,1], c=kmeans_scikit.labels_)
plt.scatter(kmeans_scikit.cluster_centers_[:,0], 
            kmeans_scikit.cluster_centers_[:,1], marker='^', c='red', s=100)
plt.show()
# Out:
# Inércia =  322.2816358499662

# %% [markdown]
# # Pymove Testes

# %%
import pymove
from pymove import MoveDataFrame

# %%
move_df = MoveDataFrame(data=all_data, latitude="LATITUDE", longitude="LONGITUDE", datetime="DATAOCORRENCIA", traj_id="NUM_BO")

# %%
#all_data.to_csv(index=False, doublequote=False, decimal='.',quoting=csv.QUOTE_NONE)

# %%
#pymove.visualization.folium.cluster(move_df)

# %%
# import pandas as pd, numpy as np, matplotlib.pyplot as plt
# from sklearn.cluster import DBSCAN
# from geopy.distance import great_circle
# from shapely.geometry import MultiPoint

# coords = np.array(df[['LATITUDE','LONGITUDE']])

# %%
# coords

# %%
# coords = df[['LATITUDE','LONGITUDE']][:1000]

# %%
# kms_per_radian = 6371.0088
# epsilon = 1.5 / kms_per_radian
# db = DBSCAN(eps=epsilon, min_samples=5, algorithm='ball_tree', metric='haversine').fit(np.radians(dataf))
# cluster_labels = db.labels_
# num_clusters = len(set(cluster_labels))
# clusters = pd.Series([dataf[cluster_labels == n] for n in range(num_clusters)])
# print('Number of clusters: {}'.format(num_clusters))

# %%
# def get_centermost_point(cluster):
#     centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
#     centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
#     return tuple(centermost_point)
# centermost_points = clusters.map(get_centermost_point)

# %%
# lats, lons = zip(*centermost_points)
# rep_points = pd.DataFrame({'lon':lons, 'lat':lats})

# %%
# rs = rep_points.apply(lambda row: coords[(coords['LATITUDE']==row['lat']) & (coords['LONGITUDE']==row['lon'])].iloc[0], axis=1)

# %%
# fig, ax = plt.subplots(figsize=[10, 6])
# rs_scatter = ax.scatter(rs['LONGITUDE'], rs['LATITUDE'], c='#99cc99', edgecolor='None', alpha=0.7, s=120)
# df_scatter = ax.scatter(coords['LONGITUDE'], coords['LATITUDE'], c='k', alpha=0.9, s=3)
# ax.set_title('Full data set vs DBSCAN reduced set')
# ax.set_xlabel('Longitude')
# ax.set_ylabel('Latitude')
# ax.legend([df_scatter, rs_scatter], ['Full set', 'Reduced set'], loc='upper right')
# plt.show()
